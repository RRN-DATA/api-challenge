# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint
import time

# Import API key
from api_keys import weather_api_key
#import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 583

# %%
#Practicing the data retrieval with One city LONDON

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city = "London"
query_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
response = requests.get(query_url).json()
pprint(response)

lat = response['coord']['lat']
temp = response['main']['temp']
city = response['name']
windspeed = response['wind']['speed']
cloudiness = response['clouds']['all']
humidity = response['main']['humidity']
max_temp = response['main']['temp_max']
lngitude = response['coord']['lon']
countrY = response['sys']['country']
DaTe = response['dt']

print("latitide: ", lat, "Tempe: ", temp, "City: ", city, "Windspeed: ", windspeed, "Cloudiness: ", cloudiness, "Humidity: ", humidity, "Max temp: ", max_temp, "Longitude: ", lngitude, "Country: ", countrY, "Date: ", DaTe)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1580263119,
#  'id': 2643743,
#  'main': {'feels_like': 26.98,
#           'humidity': 67,
#           'pressure': 1004,
#           'temp': 37,
#           'temp_max': 39.2,
#           'temp_min': 35.01},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1414,
#          'sunrise': 1580283854,
#          'sunset': 1580316158,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 10.29}}
# latitide:  51.51 Tempe:  37 City:  London Windspeed:  10.29 Cloudiness:  68 Humidity:  67 Max temp:  39.2 Longitude:  -0.13 Country:  GB Date:  1580263119

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
loop = ["marsa matruh", "timizart", "akola", "shingu", "pedana", "antalaha", "jaguarao", "mende", "khuzhir"]
    
cloudinessList = []
humidityList = []
cityList = []
LatList = []
tempList = []
windSpeedList = []
max_tempList = []
countryList = []
dateList = []
LongList = []
print ("Beginning the Data Retrieval")
print ('-'*50)
for citi in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&units={units}&q={citi}"
        response = requests.get(query_url).json()
        cloudinessList.append(response['clouds']['all'])
        windSpeedList.append(response['wind']['speed'])
        humidityList.append(response['main']['humidity'])
        cityList.append(response['name'])
        LatList.append(response['coord']['lat'])
        tempList.append(response['main']['temp'])
        max_tempList.append(response['main']['temp_max'])
        countryList.append(response['sys']['country'])
        dateList.append(response['dt'])
        LongList.append(response['coord']['lon'])
        print("Processing data from city", " | ", citi)
    except:
        print(citi, " not found. Skipping...")
        pass
print ('-'*50)
print ("Data Retrieval Complete")
# Out:
# Beginning the Data Retrieval
# --------------------------------------------------
# Processing data from city  |  busselton
# Processing data from city  |  yueyang
# Processing data from city  |  izberbash
# Processing data from city  |  rikitea
# belushya guba  not found. Skipping...
# Processing data from city  |  namtsy
# Processing data from city  |  thompson
# Processing data from city  |  sitka
# Processing data from city  |  port-gentil
# Processing data from city  |  ushuaia
# Processing data from city  |  chokurdakh
# Processing data from city  |  hibbing
# Processing data from city  |  east london
# Processing data from city  |  jamestown
# Processing data from city  |  roald
# Processing data from city  |  acarau
# Processing data from city  |  anadyr
# Processing data from city  |  imbituba
# Processing data from city  |  bredasdorp
# Processing data from city  |  mlonggo
# Processing data from city  |  omboue
# Processing data from city  |  veraval
# Processing data from city  |  hilo
# Processing data from city  |  cayenne
# vaitupu  not found. Skipping...
# Processing data from city  |  merauke
# Processing data from city  |  vaini
# Processing data from city  |  at-bashi
# Processing data from city  |  punta arenas
# Processing data from city  |  cherskiy
# Processing data from city  |  bambous virieux
# Processing data from city  |  atuona
# Processing data from city  |  komsomolskiy
# Processing data from city  |  albany
# palabuhanratu  not found. Skipping...
# Processing data from city  |  russell
# Processing data from city  |  esperance
# Processing data from city  |  cidreira
# Processing data from city  |  cape town
# Processing data from city  |  saint george
# Processing data from city  |  lebu
# Processing data from city  |  dumai
# Processing data from city  |  saldanha
# Processing data from city  |  mataura
# Processing data from city  |  mahebourg
# Processing data from city  |  arraial do cabo
# Processing data from city  |  bintulu
# Processing data from city  |  khandbari
# Processing data from city  |  barrow
# Processing data from city  |  hengyang
# taolanaro  not found. Skipping...
# Processing data from city  |  tete
# Processing data from city  |  nemuro
# Processing data from city  |  bengkulu
# Processing data from city  |  port alfred
# Processing data from city  |  georgetown
# Processing data from city  |  kaniama
# nizhneyansk  not found. Skipping...
# Processing data from city  |  korla
# Processing data from city  |  torbay
# mutsamudu  not found. Skipping...
# Processing data from city  |  tazmalt
# Processing data from city  |  coquimbo
# wulanhaote  not found. Skipping...
# Processing data from city  |  dikson
# Processing data from city  |  san rafael
# Processing data from city  |  saint-philippe
# Processing data from city  |  ilebo
# Processing data from city  |  san patricio
# grand river south east  not found. Skipping...
# Processing data from city  |  buan
# Processing data from city  |  natchez
# Processing data from city  |  tuktoyaktuk
# Processing data from city  |  ternate
# Processing data from city  |  norman wells
# samusu  not found. Skipping...
# Processing data from city  |  grand gaube
# Processing data from city  |  geraldton
# Processing data from city  |  prince rupert
# Processing data from city  |  port hardy
# Processing data from city  |  maryville
# Processing data from city  |  upernavik
# Processing data from city  |  parainen
# Processing data from city  |  abha
# Processing data from city  |  hithadhoo
# Processing data from city  |  itupiranga
# Processing data from city  |  adrar
# Processing data from city  |  henties bay
# Processing data from city  |  tiksi
# Processing data from city  |  agadir
# karaul  not found. Skipping...
# Processing data from city  |  kapaa
# Processing data from city  |  mandalgovi
# Processing data from city  |  ambilobe
# Processing data from city  |  puerto ayora
# Processing data from city  |  nikolskoye
# Processing data from city  |  kodiak
# Processing data from city  |  boyle
# umzimvubu  not found. Skipping...
# Processing data from city  |  ilulissat
# Processing data from city  |  castro
# Processing data from city  |  sibolga
# Processing data from city  |  hobart
# barentsburg  not found. Skipping...
# Processing data from city  |  mount isa
# Processing data from city  |  dire
# Processing data from city  |  qaanaaq
# Processing data from city  |  dingle
# Processing data from city  |  manga
# Processing data from city  |  naze
# Processing data from city  |  nanortalik
# Processing data from city  |  lasa
# Processing data from city  |  manoel urbano
# Processing data from city  |  talaya
# illoqqortoormiut  not found. Skipping...
# Processing data from city  |  gilgit
# Processing data from city  |  esil
# Processing data from city  |  broome
# lolua  not found. Skipping...
# Processing data from city  |  lujan
# Processing data from city  |  talcahuano
# Processing data from city  |  mar del plata
# Processing data from city  |  tuatapere
# Processing data from city  |  san bartolome de tirajana
# Processing data from city  |  sens
# Processing data from city  |  ponta do sol
# Processing data from city  |  nizhniy kuranakh
# Processing data from city  |  itoman
# Processing data from city  |  yar-sale
# Processing data from city  |  bluff
# Processing data from city  |  lazdijai
# Processing data from city  |  gazli
# Processing data from city  |  srednekolymsk
# Processing data from city  |  dori
# Processing data from city  |  ahipara
# attawapiskat  not found. Skipping...
# Processing data from city  |  severnoye
# Processing data from city  |  woodland
# Processing data from city  |  uvat
# Processing data from city  |  ancud
# Processing data from city  |  birao
# tawkar  not found. Skipping...
# Processing data from city  |  inta
# Processing data from city  |  yulara
# Processing data from city  |  muna
# Processing data from city  |  boa vista
# Processing data from city  |  la union
# Processing data from city  |  miles city
# Processing data from city  |  porto novo
# Processing data from city  |  itarema
# Processing data from city  |  tasiilaq
# Processing data from city  |  isabela
# amderma  not found. Skipping...
# ondorhaan  not found. Skipping...
# Processing data from city  |  chuy
# Processing data from city  |  charters towers
# Processing data from city  |  saskylakh
# bobonong  not found. Skipping...
# Processing data from city  |  raymondville
# Processing data from city  |  xining
# Processing data from city  |  hasaki
# Processing data from city  |  comodoro rivadavia
# mys shmidta  not found. Skipping...
# Processing data from city  |  ukiah
# Processing data from city  |  hermanus
# Processing data from city  |  gossaigaon
# Processing data from city  |  kaitangata
# Processing data from city  |  mayo
# Processing data from city  |  vostok
# Processing data from city  |  bonavista
# Processing data from city  |  alice springs
# Processing data from city  |  bad doberan
# Processing data from city  |  beringovskiy
# Processing data from city  |  brokopondo
# Processing data from city  |  sobolevo
# Processing data from city  |  mareeba
# Processing data from city  |  new norfolk
# Processing data from city  |  verkhnyaya inta
# Processing data from city  |  severo-kurilsk
# Processing data from city  |  ostrovnoy
# Processing data from city  |  nokaneng
# vreed en hoop  not found. Skipping...
# Processing data from city  |  ketchikan
# Processing data from city  |  birin
# Processing data from city  |  maridi
# Processing data from city  |  qasigiannguit
# Processing data from city  |  aginskoye
# Processing data from city  |  languyan
# Processing data from city  |  tiarei
# Processing data from city  |  laguna
# Processing data from city  |  gotsu
# Processing data from city  |  iqaluit
# Processing data from city  |  avarua
# Processing data from city  |  sinjar
# Processing data from city  |  renqiu
# Processing data from city  |  vilhena
# Processing data from city  |  bayonne
# Processing data from city  |  kruisfontein
# Processing data from city  |  morondava
# Processing data from city  |  berlevag
# Processing data from city  |  pisco
# Processing data from city  |  touros
# Processing data from city  |  bethel
# Processing data from city  |  hamilton
# Processing data from city  |  traverse city
# Processing data from city  |  khatanga
# Processing data from city  |  orlik
# Processing data from city  |  martapura
# Processing data from city  |  lima duarte
# Processing data from city  |  queimadas
# Processing data from city  |  oyotun
# Processing data from city  |  muros
# kachikau  not found. Skipping...
# Processing data from city  |  raudeberg
# Processing data from city  |  lishu
# Processing data from city  |  masunga
# Processing data from city  |  kahului
# Processing data from city  |  kedrovyy
# Processing data from city  |  davao
# Processing data from city  |  canavieiras
# Processing data from city  |  garbolovo
# Processing data from city  |  pizarro
# Processing data from city  |  diego de almagro
# Processing data from city  |  nhulunbuy
# Processing data from city  |  pevek
# Processing data from city  |  san joaquin
# Processing data from city  |  siemiatycze
# Processing data from city  |  ekibastuz
# dekoa  not found. Skipping...
# Processing data from city  |  guerrero negro
# Processing data from city  |  mackenzie
# gangotri  not found. Skipping...
# tsihombe  not found. Skipping...
# Processing data from city  |  umm lajj
# Processing data from city  |  agadez
# Processing data from city  |  kavieng
# Processing data from city  |  vredendal
# Processing data from city  |  devarkonda
# Processing data from city  |  dunedin
# Processing data from city  |  saint-joseph
# Processing data from city  |  nevers
# Processing data from city  |  airai
# Processing data from city  |  rizhao
# sentyabrskiy  not found. Skipping...
# Processing data from city  |  cartagena
# Processing data from city  |  qaqortoq
# Processing data from city  |  port macquarie
# Processing data from city  |  marystown
# Processing data from city  |  hambantota
# Processing data from city  |  carnarvon
# Processing data from city  |  butaritari
# Processing data from city  |  talnakh
# Processing data from city  |  paamiut
# Processing data from city  |  rocha
# Processing data from city  |  sistranda
# Processing data from city  |  asyut
# Processing data from city  |  the valley
# Processing data from city  |  tamworth
# Processing data from city  |  lianzhou
# Processing data from city  |  bisira
# Processing data from city  |  gat
# Processing data from city  |  palmer
# Processing data from city  |  crixas
# Processing data from city  |  port lincoln
# Processing data from city  |  longyearbyen
# Processing data from city  |  rexburg
# huitzuco  not found. Skipping...
# Processing data from city  |  jacareacanga
# Processing data from city  |  alihe
# Processing data from city  |  cairns
# Processing data from city  |  abu dhabi
# Processing data from city  |  provideniya
# chagda  not found. Skipping...
# Processing data from city  |  vila franca do campo
# Processing data from city  |  concepcion del oro
# Processing data from city  |  sarakhs
# Processing data from city  |  luderitz
# Processing data from city  |  menongue
# Processing data from city  |  kushiro
# Processing data from city  |  ponta delgada
# Processing data from city  |  saint-louis
# Processing data from city  |  coracao de jesus
# Processing data from city  |  eureka
# Processing data from city  |  sao joao da barra
# Processing data from city  |  victoria
# Processing data from city  |  tura
# Processing data from city  |  turukhansk
# Processing data from city  |  zhuhai
# Processing data from city  |  sao filipe
# Processing data from city  |  tilbury
# Processing data from city  |  kaiserslautern
# Processing data from city  |  husavik
# Processing data from city  |  taoudenni
# Processing data from city  |  nkhotakota
# Processing data from city  |  avanigadda
# Processing data from city  |  panalingaan
# Processing data from city  |  nantucket
# Processing data from city  |  okhotsk
# Processing data from city  |  coihaique
# Processing data from city  |  balangiga
# Processing data from city  |  vrangel
# Processing data from city  |  kegums
# Processing data from city  |  gospic
# Processing data from city  |  leningradskiy
# Processing data from city  |  shangrao
# Processing data from city  |  ouadda
# falealupo  not found. Skipping...
# Processing data from city  |  maceio
# Processing data from city  |  narsaq
# Processing data from city  |  maniitsoq
# Processing data from city  |  luganville
# Processing data from city  |  portland
# Processing data from city  |  brae
# Processing data from city  |  pacasmayo
# Processing data from city  |  teya
# Processing data from city  |  abu samrah
# Processing data from city  |  podor
# Processing data from city  |  pangody
# Processing data from city  |  gillette
# Processing data from city  |  hargeysa
# Processing data from city  |  lagoa
# Processing data from city  |  lavrentiya
# Processing data from city  |  jaltenango
# Processing data from city  |  maglaj
# Processing data from city  |  saint-augustin
# Processing data from city  |  avera
# Processing data from city  |  caravelas
# Processing data from city  |  kargat
# Processing data from city  |  rio gallegos
# Processing data from city  |  brandon
# Processing data from city  |  poronaysk
# samalaeulu  not found. Skipping...
# Processing data from city  |  karratha
# Processing data from city  |  katsuura
# Processing data from city  |  souillac
# Processing data from city  |  dudinka
# Processing data from city  |  scarborough
# Processing data from city  |  wamba
# Processing data from city  |  natal
# Processing data from city  |  fernley
# Processing data from city  |  galdar
# Processing data from city  |  revelstoke
# Processing data from city  |  gigmoto
# khonuu  not found. Skipping...
# Processing data from city  |  ribeira grande
# Processing data from city  |  zelenoborsk
# Processing data from city  |  minot
# Processing data from city  |  sorland
# Processing data from city  |  poplar bluff
# Processing data from city  |  ciamis
# Processing data from city  |  faanui
# Processing data from city  |  mount gambier
# Processing data from city  |  cabo san lucas
# Processing data from city  |  cangucu
# Processing data from city  |  valentin gomez farias
# Processing data from city  |  yellowknife
# Processing data from city  |  cacapava do sul
# Processing data from city  |  alot
# Processing data from city  |  suraabad
# Processing data from city  |  betong
# Processing data from city  |  minas
# Processing data from city  |  parakou
# Processing data from city  |  balabac
# Processing data from city  |  yaan
# Processing data from city  |  clyde river
# Processing data from city  |  sainte-marie
# milingimbi  not found. Skipping...
# Processing data from city  |  ayr
# Processing data from city  |  plattsburgh
# Processing data from city  |  ngunguru
# Processing data from city  |  anloga
# Processing data from city  |  vanimo
# Processing data from city  |  soc trang
# Processing data from city  |  mairena del aljarafe
# Processing data from city  |  tomiya
# crab hill  not found. Skipping...
# Processing data from city  |  dedovichi
# Processing data from city  |  samarai
# Processing data from city  |  hue
# Processing data from city  |  batangafo
# Processing data from city  |  fort nelson
# Processing data from city  |  xinzhou
# aflu  not found. Skipping...
# Processing data from city  |  strathpeffer
# Processing data from city  |  pitimbu
# Processing data from city  |  pochinki
# Processing data from city  |  port elizabeth
# Processing data from city  |  tocopilla
# Processing data from city  |  makakilo city
# Processing data from city  |  kondinskoye
# Processing data from city  |  stornoway
# Processing data from city  |  oistins
# Processing data from city  |  bundaberg
# Processing data from city  |  haapiti
# Processing data from city  |  mahibadhoo
# Processing data from city  |  sinaloa
# Processing data from city  |  te anau
# Processing data from city  |  milkovo
# Processing data from city  |  fukue
# Processing data from city  |  mackay
# Processing data from city  |  carutapera
# Processing data from city  |  gushikawa
# Processing data from city  |  floriano
# Processing data from city  |  nouadhibou
# Processing data from city  |  estelle
# Processing data from city  |  kawambwa
# Processing data from city  |  vila velha
# Processing data from city  |  singaparna
# Processing data from city  |  ozinki
# Processing data from city  |  kidal
# tumannyy  not found. Skipping...
# Processing data from city  |  challapata
# Processing data from city  |  praia
# Processing data from city  |  lorengau
# Processing data from city  |  rivera
# Processing data from city  |  sonepur
# Processing data from city  |  labuhan
# Processing data from city  |  bereda
# Processing data from city  |  saint anthony
# Processing data from city  |  aransas pass
# Processing data from city  |  kasaragod
# Processing data from city  |  amga
# Processing data from city  |  trairi
# Processing data from city  |  nenjiang
# Processing data from city  |  olafsvik
# Processing data from city  |  zhigansk
# Processing data from city  |  price
# Processing data from city  |  kuytun
# Processing data from city  |  kalmunai
# Processing data from city  |  gao
# Processing data from city  |  dhidhdhoo
# Processing data from city  |  aklavik
# Processing data from city  |  yankton
# Processing data from city  |  aykhal
# Processing data from city  |  sainte-rose
# blonduos  not found. Skipping...
# Processing data from city  |  toamasina
# kuala krai  not found. Skipping...
# Processing data from city  |  oranjemund
# Processing data from city  |  manta
# Processing data from city  |  floro
# Processing data from city  |  seoul
# Processing data from city  |  kirovskiy
# kamenskoye  not found. Skipping...
# Processing data from city  |  saint-georges
# Processing data from city  |  sisophon
# Processing data from city  |  villefontaine
# Processing data from city  |  yatou
# Processing data from city  |  camana
# Processing data from city  |  nome
# Processing data from city  |  asau
# Processing data from city  |  guiratinga
# Processing data from city  |  zemio
# Processing data from city  |  koungou
# Processing data from city  |  bilma
# Processing data from city  |  musoma
# Processing data from city  |  buala
# Processing data from city  |  nioro
# Processing data from city  |  guane
# skalistyy  not found. Skipping...
# Processing data from city  |  filadelfia
# Processing data from city  |  pafos
# Processing data from city  |  dolzhanskaya
# Processing data from city  |  port blair
# Processing data from city  |  la ronge
# Processing data from city  |  champerico
# Processing data from city  |  tombouctou
# Processing data from city  |  tilichiki
# Processing data from city  |  phan thiet
# Processing data from city  |  nushki
# Processing data from city  |  maldonado
# Processing data from city  |  marsa matruh
# Processing data from city  |  bubaque
# Processing data from city  |  san ignacio
# Processing data from city  |  sisimiut
# Processing data from city  |  goderich
# Processing data from city  |  yecapixtla
# Processing data from city  |  san felipe
# Processing data from city  |  hofn
# Processing data from city  |  yartsevo
# Processing data from city  |  lompoc
# saleaula  not found. Skipping...
# Processing data from city  |  berbera
# sumbawa  not found. Skipping...
# Processing data from city  |  ialibu
# Processing data from city  |  digras
# haibowan  not found. Skipping...
# Processing data from city  |  mezen
# Processing data from city  |  hualmay
# Processing data from city  |  bingerville
# Processing data from city  |  viedma
# Processing data from city  |  chifeng
# Processing data from city  |  puerto escondido
# Processing data from city  |  arthur
# Processing data from city  |  puerto colombia
# Processing data from city  |  forbes
# Processing data from city  |  mindelo
# Processing data from city  |  ardakan
# Processing data from city  |  mitsamiouli
# Processing data from city  |  luwuk
# Processing data from city  |  rauma
# Processing data from city  |  muzaffarabad
# Processing data from city  |  tadine
# Processing data from city  |  verkhoyansk
# ust-kamchatsk  not found. Skipping...
# halalo  not found. Skipping...
# Processing data from city  |  axim
# Processing data from city  |  kununurra
# Processing data from city  |  port-de-bouc
# Processing data from city  |  encruzilhada
# Processing data from city  |  nedjo
# Processing data from city  |  smoky lake
# louisbourg  not found. Skipping...
# Processing data from city  |  waipawa
# Processing data from city  |  vardo
# Processing data from city  |  wencheng
# Processing data from city  |  zwedru
# ario  not found. Skipping...
# marcona  not found. Skipping...
# Processing data from city  |  vestmannaeyjar
# Processing data from city  |  aljezur
# Processing data from city  |  yeniseysk
# karauzyak  not found. Skipping...
# Processing data from city  |  bhera
# Processing data from city  |  meulaboh
# Processing data from city  |  montrose
# Processing data from city  |  sungaipenuh
# Processing data from city  |  hammerfest
# Processing data from city  |  thinadhoo
# Processing data from city  |  isangel
# Processing data from city  |  puerto madero
# Processing data from city  |  pangnirtung
# Processing data from city  |  flinders
# Processing data from city  |  abay
# Processing data from city  |  penzance
# buqayq  not found. Skipping...
# borujan  not found. Skipping...
# Processing data from city  |  bangkalan
# Processing data from city  |  grindavik
# Processing data from city  |  zaysan
# Processing data from city  |  muisne
# Processing data from city  |  kuloy
# Processing data from city  |  biltine
# Processing data from city  |  skjervoy
# Processing data from city  |  marzuq
# Processing data from city  |  kachiry
# Processing data from city  |  bumba
# Processing data from city  |  jizan
# Processing data from city  |  gambela
# Processing data from city  |  bireun
# Processing data from city  |  qui nhon
# Processing data from city  |  gravdal
# Processing data from city  |  chapais
# rungata  not found. Skipping...
# jabiru  not found. Skipping...
# Processing data from city  |  bunbury
# Processing data from city  |  galveston
# Processing data from city  |  terrace
# Processing data from city  |  jimenez
# Processing data from city  |  sheksna
# Processing data from city  |  miamisburg
# Processing data from city  |  la serena
# Processing data from city  |  temerloh
# Processing data from city  |  takoradi
# burkhala  not found. Skipping...
# Processing data from city  |  carupano
# Processing data from city  |  poso
# Processing data from city  |  svetlyy
# Processing data from city  |  simbahan
# Processing data from city  |  beckley
# Processing data from city  |  hailar
# Processing data from city  |  ulaanbaatar
# Processing data from city  |  bolobo
# Processing data from city  |  yumen
# acutzilapan  not found. Skipping...
# Processing data from city  |  svetlogorsk
# Processing data from city  |  katsuyama
# Processing data from city  |  lata
# Processing data from city  |  margate
# Processing data from city  |  bandarbeyla
# Processing data from city  |  bulgan
# Processing data from city  |  constitucion
# Processing data from city  |  benguela
# Processing data from city  |  novikovo
# Processing data from city  |  half moon bay
# Processing data from city  |  autazes
# Processing data from city  |  progreso
# Processing data from city  |  kolvereid
# Processing data from city  |  mana
# Processing data from city  |  calceta
# Processing data from city  |  ozernovskiy
# Processing data from city  |  gamba
# Processing data from city  |  sinnamary
# Processing data from city  |  nanakuli
# Processing data from city  |  partenit
# Processing data from city  |  kyren
# Processing data from city  |  la palma
# Processing data from city  |  hovd
# Processing data from city  |  teofilo otoni
# Processing data from city  |  barreirinhas
# Processing data from city  |  shimoda
# Processing data from city  |  bathsheba
# Processing data from city  |  harper
# Processing data from city  |  nanhai
# Processing data from city  |  lujiang
# Processing data from city  |  hirado
# Processing data from city  |  namatanai
# Processing data from city  |  shizunai
# Processing data from city  |  esplanada
# Processing data from city  |  santa cruz de tenerife
# kuche  not found. Skipping...

# %%
citiIndex = []
for index, city in np.ndenumerate(cityList):
    citiIndex.append(index[0])

new_dateList = []
for date in dateList:
        date = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(date))
        new_dateList.append(date)
# Out:
# 556

# %%
print ("City ID: ", len(citiIndex))
#print ("City List: ", len(cityList))
#print ("Cloudiness: ", len(cloudinessList))
#print ("Country: ", len(countryList))
#print ("Date: ", len(new_dateList))
#print ("Humidity: ", len(humidityList))
#print ("Latitudes: ", len(LatList))
#print ("Longitude: ", len(LongList))
#print ("Max Temperatures:", len(max_tempList))
#print ("Wind Speed: ", len(windSpeedList))
# Out:
# City ID:  556
# City List:  556
# Cloudiness:  556
# Country:  556
# Date:  556
# Humidity:  556
# Latitudes:  556
# Longitude:  556
# Max Temperatures: 556
# Wind Speed:  556

# %%
citi_df = pd.DataFrame({"City_ID": citiIndex, "City": cityList, "Cloudiness": cloudinessList, "Country": countryList, "Date": new_dateList, "Humidity": humidityList, "Lat": LatList, "Lng": LongList, "Max Temp": max_tempList, "Wind Speed": windSpeedList})
citi_df.head()
# Out:
#    City_ID       City  Cloudiness Country                 Date  Humidity  \
# 0        0  Busselton          32      AU  2020-01-28 20:58:52        30
# 1        1    Yueyang          27      CN  2020-01-28 21:03:16        58
# 2        2  Izberbash          20      RU  2020-01-28 21:03:18        86
# 3        3    Rikitea         100      PF  2020-01-28 21:03:21        78
# 4        4     Namtsy           1      RU  2020-01-28 21:03:32        64
#
#      Lat     Lng  Max Temp  Wind Speed
# 0 -33.65  115.33     84.99        7.54
# 1  29.33  113.09     46.92        4.79
# 2  42.57   47.86     33.80        8.95
# 3 -23.12 -134.97     79.79        6.22
# 4  62.72  129.67    -41.80        2.24

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citi_df.to_csv(r'cities.csv', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_values = LatList
y_values = max_tempList
fig1, ax1 = plt.subplots()
plt.scatter(x_values, y_values, marker="h", facecolors="purple", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_values = LatList
y_values = humidityList
fig2, ax2 = plt.subplots()
plt.scatter(x_values, y_values, marker="h", facecolors="red", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# Out:
# Text(0, 0.5, 'Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_values = LatList
y_values = cloudinessList
fig3, ax3 = plt.subplots()
plt.scatter(x_values, y_values, marker="h", facecolors="orange", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_values = LatList
y_values = windSpeedList
fig4, ax4 = plt.subplots()
plt.scatter(x_values, y_values, marker="h", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Latitude vs Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linearRegressionPlots(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = citi_df.loc[citi_df['Lat']>0]
south_df = citi_df.loc[citi_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_df['Max Temp']
y_values = north_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig5, ax5 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Maximum Temperature')
plt.ylabel('Latitude')
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.figure(figsize=(6,3))
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_df['Max Temp']
y_values = south_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig6, ax6 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Max Temp')
plt.ylabel('Latitude')
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.figure(figsize=(6,3))
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Humidity']
y_values = north_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig7, ax7 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Humidity (%)')
plt.ylabel('Latitude')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Humidity']
y_values = south_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig8, ax8 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Humidity (%)')
plt.ylabel('Latitude')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Cloudiness']
y_values = north_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig9, ax9 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Cloudiness (%)')
plt.ylabel('Latitude')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Cloudiness']
y_values = south_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig10, ax10 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Cloudiness (%)')
plt.ylabel('Latitude')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df['Wind Speed']
y_values = north_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig11, ax11 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df['Wind Speed']
y_values = south_df['Lat']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig12, ax12 = plt.subplots()
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.show()
